# %%
from pypekit import Task
import pandas as pd


class IrisLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, _):
        from sklearn.datasets import load_iris
        iris = load_iris()
        iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
        iris_df['target'] = iris.target
        return iris_df


class TrainTestSplitter(Task):
    input_types = ["raw"]
    output_types = ["split"]

    def run(self, df):
        from sklearn.model_selection import train_test_split
        train_df, test_df = train_test_split(df, test_size=0.2)
        train_df['train'] = 1
        test_df['train'] = 0
        df = pd.concat([train_df, test_df], ignore_index=True)
        return df


class Scaler(Task):
    input_types = ["split"]
    output_types = ["processed"]

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        scaler = self.get_scaler()
        scaler.fit(X_train)

        X_scaled = scaler.transform(X)
        scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns)
        scaled_df['target'] = df['target']
        scaled_df['train'] = df['train']

        return scaled_df

    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class MinMaxScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import MinMaxScaler
        return MinMaxScaler()


class StandardScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import StandardScaler
        return StandardScaler()


class PCA(Task):
    input_types = ["split", "processed"]
    output_types = ["processed"]

    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        from sklearn.decomposition import PCA
        pca = PCA(**self.kwargs)
        pca.fit(X_train)

        X_pca = pca.transform(X)
        pca_df = pd.DataFrame(data=X_pca, columns=[
                              f'PC[i+1]' for i in range(X_pca.shape[1])])
        pca_df['target'] = df['target']
        pca_df['train'] = df['train']

        return pca_df


class Classifier(Task):
    input_types = ["split", "processed"]
    output_types = ["processed", "predicted"]

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        y = df['target']
        X_train = X[df['train'] == 1]
        y_train = y[df['train'] == 1]

        classifier = self.get_classifier()
        classifier.fit(X_train, y_train)
        
        y_pred = classifier.predict(X)
        df['predicted'] = y_pred

        return df
    
    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class LogisticRegression(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.linear_model import LogisticRegression
        return LogisticRegression(**self.kwargs)


class RandomForestClassifier(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.ensemble import RandomForestClassifier
        return RandomForestClassifier(**self.kwargs)


class SVC(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.svm import SVC
        return SVC(**self.kwargs)


class Evaluator(Task):
    input_types = ["predicted"]
    output_types = ["sink"]

    def run(self, df):
        df_test = df[df['train'] == 0]
        return (df_test['target'] == df_test['predicted']).mean()

# %%
from pypekit import Repository, CachedExecutor

repository = Repository([
    IrisLoader,
    TrainTestSplitter,
    MinMaxScaler,
    StandardScaler,
    PCA,
    LogisticRegression,
    RandomForestClassifier,
    SVC,
    Evaluator
])

repository.build_tree()
print(repository.build_tree_string())
# Out:
# └── Root
#     └── IrisLoader
#         └── TrainTestSplitter
#             ├── MinMaxScaler
#             │   ├── PCA
#             │   │   ├── LogisticRegression
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   ├── RandomForestClassifier
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   ├── LogisticRegression
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── SVC
#             │   │       ├── LogisticRegression
#             │   │       │   ├── RandomForestClassifier
#             │   │       │   │   └── Evaluator
#             │   │       │   └── Evaluator
#             │   │       ├── RandomForestClassifier
#             │   │       │   ├── LogisticRegression
#             │   │       │   │   └── Evaluator
#             │   │       │   └── Evaluator
#             │   │       └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── PCA
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── SVC
#             │   │   │       ├── RandomForestClassifier
#             │   │   │       │   └── Evaluator
#             │   │   │       └── Evaluator
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── PCA
#             │   │   │   │   └── SVC
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── PCA
#             │   │   │   │   └── RandomForestClassifier
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   ├── RandomForestClassifier
#             │   │   ├── PCA
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── SVC
#             │   │   │       ├── LogisticRegression
#             │   │   │       │   └── Evaluator
#             │   │   │       └── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── PCA
#             │   │   │   │   └── SVC
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── PCA
#             │   │   │   │   └── LogisticRegression
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   └── SVC
#             │       ├── PCA
#             │       │   ├── LogisticRegression
#             │       │   │   ├── RandomForestClassifier
#             │       │   │   │   └── Evaluator
#             │       │   │   └── Evaluator
#             │       │   └── RandomForestClassifier
#             │       │       ├── LogisticRegression
#             │       │       │   └── Evaluator
#             │       │       └── Evaluator
#             │       ├── LogisticRegression
#             │       │   ├── PCA
#             │       │   │   └── RandomForestClassifier
#             │       │   │       └── Evaluator
#             │       │   ├── RandomForestClassifier
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       ├── RandomForestClassifier
#             │       │   ├── PCA
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   ├── LogisticRegression
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       └── Evaluator
#             ├── StandardScaler
#             │   ├── PCA
#             │   │   ├── LogisticRegression
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   ├── RandomForestClassifier
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   ├── LogisticRegression
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── SVC
#             │   │       ├── LogisticRegression
#             │   │       │   ├── RandomForestClassifier
#             │   │       │   │   └── Evaluator
#             │   │       │   └── Evaluator
#             │   │       ├── RandomForestClassifier
#             │   │       │   ├── LogisticRegression
#             │   │       │   │   └── Evaluator
#             │   │       │   └── Evaluator
#             │   │       └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── PCA
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── SVC
#             │   │   │       ├── RandomForestClassifier
#             │   │   │       │   └── Evaluator
#             │   │   │       └── Evaluator
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── PCA
#             │   │   │   │   └── SVC
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── PCA
#             │   │   │   │   └── RandomForestClassifier
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   ├── RandomForestClassifier
#             │   │   ├── PCA
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   ├── SVC
#             │   │   │   │   │   └── Evaluator
#             │   │   │   │   └── Evaluator
#             │   │   │   └── SVC
#             │   │   │       ├── LogisticRegression
#             │   │   │       │   └── Evaluator
#             │   │   │       └── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── PCA
#             │   │   │   │   └── SVC
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── PCA
#             │   │   │   │   └── LogisticRegression
#             │   │   │   │       └── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   └── SVC
#             │       ├── PCA
#             │       │   ├── LogisticRegression
#             │       │   │   ├── RandomForestClassifier
#             │       │   │   │   └── Evaluator
#             │       │   │   └── Evaluator
#             │       │   └── RandomForestClassifier
#             │       │       ├── LogisticRegression
#             │       │       │   └── Evaluator
#             │       │       └── Evaluator
#             │       ├── LogisticRegression
#             │       │   ├── PCA
#             │       │   │   └── RandomForestClassifier
#             │       │   │       └── Evaluator
#             │       │   ├── RandomForestClassifier
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       ├── RandomForestClassifier
#             │       │   ├── PCA
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   ├── LogisticRegression
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       └── Evaluator
#             ├── PCA
#             │   ├── LogisticRegression
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   ├── RandomForestClassifier
#             │   │   ├── LogisticRegression
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   └── SVC
#             │       ├── LogisticRegression
#             │       │   ├── RandomForestClassifier
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       ├── RandomForestClassifier
#             │       │   ├── LogisticRegression
#             │       │   │   └── Evaluator
#             │       │   └── Evaluator
#             │       └── Evaluator
#             ├── LogisticRegression
#             │   ├── PCA
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── SVC
#             │   │       ├── RandomForestClassifier
#             │   │       │   └── Evaluator
#             │   │       └── Evaluator
#             │   ├── RandomForestClassifier
#             │   │   ├── PCA
#             │   │   │   └── SVC
#             │   │   │       └── Evaluator
#             │   │   ├── SVC
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   ├── SVC
#             │   │   ├── PCA
#             │   │   │   └── RandomForestClassifier
#             │   │   │       └── Evaluator
#             │   │   ├── RandomForestClassifier
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   └── Evaluator
#             ├── RandomForestClassifier
#             │   ├── PCA
#             │   │   ├── LogisticRegression
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── Evaluator
#             │   │   └── SVC
#             │   │       ├── LogisticRegression
#             │   │       │   └── Evaluator
#             │   │       └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── PCA
#             │   │   │   └── SVC
#             │   │   │       └── Evaluator
#             │   │   ├── SVC
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   ├── SVC
#             │   │   ├── PCA
#             │   │   │   └── LogisticRegression
#             │   │   │       └── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   └── Evaluator
#             │   │   └── Evaluator
#             │   └── Evaluator
#             └── SVC
#                 ├── PCA
#                 │   ├── LogisticRegression
#                 │   │   ├── RandomForestClassifier
#                 │   │   │   └── Evaluator
#                 │   │   └── Evaluator
#                 │   └── RandomForestClassifier
#                 │       ├── LogisticRegression
#                 │       │   └── Evaluator
#                 │       └── Evaluator
#                 ├── LogisticRegression
#                 │   ├── PCA
#                 │   │   └── RandomForestClassifier
#                 │   │       └── Evaluator
#                 │   ├── RandomForestClassifier
#                 │   │   └── Evaluator
#                 │   └── Evaluator
#                 ├── RandomForestClassifier
#                 │   ├── PCA
#                 │   │   └── LogisticRegression
#                 │   │       └── Evaluator
#                 │   ├── LogisticRegression
#                 │   │   └── Evaluator
#                 │   └── Evaluator
#                 └── Evaluator

# %%
pipelines = repository.build_pipelines()
pipelines[:10]
# Out:
# [Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'Evaluator'])]

# %%
executor = CachedExecutor(pipelines, verbose=True)
results = executor.run()
# Out:
# Pipeline 1/144 completed. Runtime: 0.57s.
# Pipeline 2/144 completed. Runtime: 0.56s.
# Pipeline 3/144 completed. Runtime: 0.52s.
# Pipeline 4/144 completed. Runtime: 0.47s.
# Pipeline 5/144 completed. Runtime: 0.46s.
# Pipeline 6/144 completed. Runtime: 0.51s.
# Pipeline 7/144 completed. Runtime: 0.51s.
# Pipeline 8/144 completed. Runtime: 0.51s.
# Pipeline 9/144 completed. Runtime: 0.50s.
# Pipeline 10/144 completed. Runtime: 0.50s.
# Pipeline 11/144 completed. Runtime: 0.53s.
# Pipeline 12/144 completed. Runtime: 0.45s.
# Pipeline 13/144 completed. Runtime: 0.51s.
# Pipeline 14/144 completed. Runtime: 0.50s.
# Pipeline 15/144 completed. Runtime: 0.45s.
# Pipeline 16/144 completed. Runtime: 0.54s.
# Pipeline 17/144 completed. Runtime: 0.53s.
# Pipeline 18/144 completed. Runtime: 0.51s.
# Pipeline 19/144 completed. Runtime: 0.45s.
# Pipeline 20/144 completed. Runtime: 0.51s.
# Pipeline 21/144 completed. Runtime: 0.51s.
# Pipeline 22/144 completed. Runtime: 0.51s.
# Pipeline 23/144 completed. Runtime: 0.51s.
# Pipeline 24/144 completed. Runtime: 0.51s.
# Pipeline 25/144 completed. Runtime: 0.45s.
# Pipeline 26/144 completed. Runtime: 0.45s.
# Pipeline 27/144 completed. Runtime: 0.48s.
# Pipeline 28/144 completed. Runtime: 0.47s.
# Pipeline 29/144 completed. Runtime: 0.48s.
# Pipeline 30/144 completed. Runtime: 0.47s.
# Pipeline 31/144 completed. Runtime: 0.47s.
# Pipeline 32/144 completed. Runtime: 0.47s.
# Pipeline 33/144 completed. Runtime: 0.47s.
# Pipeline 34/144 completed. Runtime: 0.48s.
# Pipeline 35/144 completed. Runtime: 0.47s.
# Pipeline 36/144 completed. Runtime: 0.47s.
# Pipeline 37/144 completed. Runtime: 0.47s.
# Pipeline 38/144 completed. Runtime: 0.49s.
# Pipeline 39/144 completed. Runtime: 0.42s.
# Pipeline 40/144 completed. Runtime: 0.47s.
# Pipeline 41/144 completed. Runtime: 0.47s.
# Pipeline 42/144 completed. Runtime: 0.50s.
# Pipeline 43/144 completed. Runtime: 0.47s.
# Pipeline 44/144 completed. Runtime: 0.42s.
# Pipeline 45/144 completed. Runtime: 0.47s.
# Pipeline 46/144 completed. Runtime: 0.47s.
# Pipeline 47/144 completed. Runtime: 0.47s.
# Pipeline 48/144 completed. Runtime: 0.41s.
# Pipeline 49/144 completed. Runtime: 0.50s.
# Pipeline 50/144 completed. Runtime: 0.49s.
# Pipeline 51/144 completed. Runtime: 0.48s.
# Pipeline 52/144 completed. Runtime: 0.42s.
# Pipeline 53/144 completed. Runtime: 0.42s.
# Pipeline 54/144 completed. Runtime: 0.48s.
# Pipeline 55/144 completed. Runtime: 0.48s.
# Pipeline 56/144 completed. Runtime: 0.48s.
# Pipeline 57/144 completed. Runtime: 0.47s.
# Pipeline 58/144 completed. Runtime: 0.47s.
# Pipeline 59/144 completed. Runtime: 0.49s.
# Pipeline 60/144 completed. Runtime: 0.42s.
# Pipeline 61/144 completed. Runtime: 0.47s.
# Pipeline 62/144 completed. Runtime: 0.47s.
# Pipeline 63/144 completed. Runtime: 0.41s.
# Pipeline 64/144 completed. Runtime: 0.50s.
# Pipeline 65/144 completed. Runtime: 0.49s.
# Pipeline 66/144 completed. Runtime: 0.47s.
# Pipeline 67/144 completed. Runtime: 0.42s.
# Pipeline 68/144 completed. Runtime: 0.48s.
# Pipeline 69/144 completed. Runtime: 0.47s.
# Pipeline 70/144 completed. Runtime: 0.47s.
# Pipeline 71/144 completed. Runtime: 0.48s.
# Pipeline 72/144 completed. Runtime: 0.47s.
# Pipeline 73/144 completed. Runtime: 0.42s.
# Pipeline 74/144 completed. Runtime: 0.41s.
# Pipeline 75/144 completed. Runtime: 0.47s.
# Pipeline 76/144 completed. Runtime: 0.47s.
# Pipeline 77/144 completed. Runtime: 0.47s.
# Pipeline 78/144 completed. Runtime: 0.47s.
# Pipeline 79/144 completed. Runtime: 0.47s.
# Pipeline 80/144 completed. Runtime: 0.47s.
# Pipeline 81/144 completed. Runtime: 0.47s.
# Pipeline 82/144 completed. Runtime: 0.47s.
# Pipeline 83/144 completed. Runtime: 0.47s.
# Pipeline 84/144 completed. Runtime: 0.47s.
# Pipeline 85/144 completed. Runtime: 0.47s.
# Pipeline 86/144 completed. Runtime: 0.49s.
# Pipeline 87/144 completed. Runtime: 0.42s.
# Pipeline 88/144 completed. Runtime: 0.48s.
# Pipeline 89/144 completed. Runtime: 0.47s.
# Pipeline 90/144 completed. Runtime: 0.50s.
# Pipeline 91/144 completed. Runtime: 0.47s.
# Pipeline 92/144 completed. Runtime: 0.42s.
# Pipeline 93/144 completed. Runtime: 0.47s.
# Pipeline 94/144 completed. Runtime: 0.47s.
# Pipeline 95/144 completed. Runtime: 0.47s.
# Pipeline 96/144 completed. Runtime: 0.41s.
# Pipeline 97/144 completed. Runtime: 0.49s.
# Pipeline 98/144 completed. Runtime: 0.49s.
# Pipeline 99/144 completed. Runtime: 0.47s.
# Pipeline 100/144 completed. Runtime: 0.42s.
# Pipeline 101/144 completed. Runtime: 0.41s.
# Pipeline 102/144 completed. Runtime: 0.47s.
# Pipeline 103/144 completed. Runtime: 0.47s.
# Pipeline 104/144 completed. Runtime: 0.47s.
# Pipeline 105/144 completed. Runtime: 0.47s.
# Pipeline 106/144 completed. Runtime: 0.47s.
# Pipeline 107/144 completed. Runtime: 0.48s.
# Pipeline 108/144 completed. Runtime: 0.42s.
# Pipeline 109/144 completed. Runtime: 0.47s.
# Pipeline 110/144 completed. Runtime: 0.47s.
# Pipeline 111/144 completed. Runtime: 0.41s.
# Pipeline 112/144 completed. Runtime: 0.50s.
# Pipeline 113/144 completed. Runtime: 0.50s.
# Pipeline 114/144 completed. Runtime: 0.48s.
# Pipeline 115/144 completed. Runtime: 0.42s.
# Pipeline 116/144 completed. Runtime: 0.48s.
# Pipeline 117/144 completed. Runtime: 0.48s.
# Pipeline 118/144 completed. Runtime: 0.47s.
# Pipeline 119/144 completed. Runtime: 0.48s.
# Pipeline 120/144 completed. Runtime: 0.48s.
# Pipeline 121/144 completed. Runtime: 0.42s.
# Pipeline 122/144 completed. Runtime: 0.42s.
# Pipeline 123/144 completed. Runtime: 0.47s.
# Pipeline 124/144 completed. Runtime: 0.47s.
# Pipeline 125/144 completed. Runtime: 0.47s.
# Pipeline 126/144 completed. Runtime: 0.47s.
# Pipeline 127/144 completed. Runtime: 0.48s.
# Pipeline 128/144 completed. Runtime: 0.47s.
# Pipeline 129/144 completed. Runtime: 0.47s.
# Pipeline 130/144 completed. Runtime: 0.47s.
# Pipeline 131/144 completed. Runtime: 0.47s.
# Pipeline 132/144 completed. Runtime: 0.47s.
# Pipeline 133/144 completed. Runtime: 0.46s.
# Pipeline 134/144 completed. Runtime: 0.49s.
# Pipeline 135/144 completed. Runtime: 0.42s.
# Pipeline 136/144 completed. Runtime: 0.47s.
# Pipeline 137/144 completed. Runtime: 0.47s.
# Pipeline 138/144 completed. Runtime: 0.49s.
# Pipeline 139/144 completed. Runtime: 0.47s.
# Pipeline 140/144 completed. Runtime: 0.42s.
# Pipeline 141/144 completed. Runtime: 0.47s.
# Pipeline 142/144 completed. Runtime: 0.47s.
# Pipeline 143/144 completed. Runtime: 0.46s.
# Pipeline 144/144 completed. Runtime: 0.41s.

# %%
for r in results.values():
    print(r)
# Out:
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5655068500018388, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5634896670053422, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5202032740053255, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.46578666400455404, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4630161620043509, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5070820420041855, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5050535170084913, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5061104330052331, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5027118290017825, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5008444100021734, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5256398989986337, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.44923308299985365, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5097022570007539, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5044993929950579, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.44592963800096186, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5368864129923168, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5347802409960423, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5121687379978539, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.45417128299959586, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5110790809958417, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5075310239953978, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5061222909971548, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.5116188790016167, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.509443248003663, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4516610270002275, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4497478699995554, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47541639799965196, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.472918056002527, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47553424099533004, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4716780419985298, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4743084629990335, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47202915599700646, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4700720459986769, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47653232899756404, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47376900300150737, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4692591589955555, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.46719306399609195, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4928372739923361, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.41762607299824595, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47460873700038064, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4705228940001689, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4975390659965342, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47053674299968407, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4150705609972647, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47165636299178004, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4685726939896995, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4660437229977106, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4124294399989594, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.49653488299736637, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4940024259958591, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47684051699980046, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.41747949999626144, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.41500896599609405, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4789806869957829, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4766089339973405, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47758197199800634, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47428899799342616, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47235574499791255, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4869671450032911, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.416666470002383, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4748037619974639, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4711219929959043, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4141210979978496, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.49536212499515386, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.492816933994618, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47269932099516154, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.41780927799845813, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4763381650009251, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47106229799828725, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4688142080012767, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.477707518999523, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4697955029987497, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.41542268700140994, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4134600479992514, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4734036349946109, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47105586599718663, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4734934389962291, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.46992902099736966, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4722733799935668, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4702487159993325, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.468192383996211, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4730476410004485, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4706301709993568, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.46816613400005735, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4653216779988725, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.48675811100474675, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.41927843700614176, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4784105210019334, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4735693610018643, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4974166129977675, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4695405700003903, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4154588160017738, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.47095488700142596, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4686926559988933, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4657127480022609, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.4128858130025037, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4918626310027321, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4892957100055355, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4717704060021788, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.41553742600081023, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.41350456299915095, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4716925250068016, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.46996815500824596, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4706114120053826, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4678248340023856, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.46608670800196705, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.48374942000737065, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4151198270083114, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47307793000072706, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4693916230025934, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4123703290024423, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4976396390047739, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4952845470033935, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4751695910017588, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.42125590200157603, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4774089019992971, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4754092430048331, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47343636399818934, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4790647240006365, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4757641229989531, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4185140599984152, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.41723988100056886, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47455215499940095, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4713320540031418, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4724360139989585, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4688343680027174, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.476829278999503, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4738678410030843, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47174863500185893, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4724443920022168, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47469017800176516, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.46675194300405565, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.46410373600156163, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.48920687300051213, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4156161220053036, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47451667800487485, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4707709370049997, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.49100511600408936, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4732300079995184, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4181212700023025, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4695703380020859, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.47230446500179823, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.4643492290015274, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(1.0), 'runtime': 0.41105565300313174, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'Evaluator']}
