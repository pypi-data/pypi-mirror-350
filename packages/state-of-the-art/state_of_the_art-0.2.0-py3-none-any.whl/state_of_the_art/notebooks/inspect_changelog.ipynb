# %%
from state_of_the_art.tables.changelog_table import Changelog

changelog = Changelog()

changelog.read(recent_first=True)
# Out:
#                                              message by_user  \
# 0  Mined keyword: 'media mix modelling mmm market...    None
# 0  Mined keyword: 'media mix modelling mmm market...    None
# 0  Mined keyword: 'media mix modelling mmm market...    None
# 0  Mined keyword: 'media mix modelling mmm market...    None
# 0     Mined keyword: 'media mix modelling marketing'    None
# 0       Mined keyword: media mix modelling marketing    None
# 0       Mined keyword: media mix modelling marketing    None
#
#                tdw_timestamp                              tdw_uuid
# 0 2024-12-03 21:52:01.870385  75302654-93e0-490e-a159-48cf86bbbf76
# 0 2024-12-03 21:42:21.067925  0c0e2cd9-887a-4861-82ef-7bfa9758eb20
# 0 2024-12-03 21:42:07.953326  781ef81e-7bd0-492c-96aa-acbe5654b189
# 0 2024-12-03 21:40:44.853201  5cec378a-e02e-43b4-a812-8134ce67a8e0
# 0 2024-12-03 21:40:31.203621  aab2b7f1-02a0-4434-97b9-d81f82a5c53a
# 0 2024-12-03 21:40:12.128741  906614e4-5664-42ae-835d-eafa7cf08474
# ...
