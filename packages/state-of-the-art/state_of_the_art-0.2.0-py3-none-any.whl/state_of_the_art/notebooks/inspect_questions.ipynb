# %%
from state_of_the_art.tables.questions_table import QuestionsTable
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)


QuestionsTable().read()[['short_version', 'question']]
# Out:
#                    short_version  \
# 0                    Institution
# 1                     Conference
# 2         DeepSummaryOfStructure
# 3                         Unique
# 4                      Weakeness
# 5                      Resources
# 6                    Definitions
# 7                    TopInsights
# 8                       Outcomes
# 9              ExplainForFriends
# 10       ConcreteFollowupActions
# 11                30secondsPitch
# 12                  KeyTakeAways
# 13   ImagesAndFiguresAndFormulas
# 14             HowTheyAchievedit
# 15  RelevanceOfInsitutionOnTopic
# 16             LiteralHighlights
#
#                                                                                                                                                                                                                                                  question
# 0                                                                                                                                                                                                  Which institution or insitutions  published the paper?
# 1                                                                                                                                                                                                           In which conference was this paper published?
# 2                                                                                                                                                                                           Summarize the core of the paper going into detail when needed
# 3                                                                                                                                                                                                                        What is unique about this paper?
# 4                                                                                                                                                                                                                      What are weakenesses of the paper?
# 5   Return further resources recommendations from the board of experts if somebody wants to go deep into it. Books, articles, papers, people, organization or conferences to follow related to the topic that helps to get a deeper understanding of it.
# 6                                                                                                                                                                      define core terms in the paper use analogies if needed when they are very complete
# 7                                                                                                                                                                                                                What are the top insights from the paper
# 8                                                                                                                                                                  What are the real outcomes of the paper? Anything trully novel that can be acted upon?
# 9                                                                                                                          If i want to start a conversation with frinds on how cool this paper is how should i describe it to a scientific minded person
# 10                                                                                                                                                               Assuming the paper claims are true, what one should do in the day to day to act on them?
# 11                                                                                                                                                                                             Explain if i should read this paper and why in 30 seconds.
# 12                                                                                                                                                                                  After reading this papers what are the learnings that stick the most?
# 13                                                                                                                                                               Are there any very impactful images or formulas that will help my learning on the paper?
# 14                                                                                                                                                                              Go in detail on the core achievement and how it was solved by the authors
# 15                                                                                     Explain about this institution and how big it is in the field its reporting about, so we have a sense of how impactful it can be given their history on the topic.
# 16                                                                                                      Selects literal parts of the text that have high informational value. Maximizes diversity from the areas picking insights from the whole content.
