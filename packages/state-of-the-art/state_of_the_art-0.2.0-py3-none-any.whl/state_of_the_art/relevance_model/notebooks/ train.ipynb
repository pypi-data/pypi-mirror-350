# %%
# %load_ext autoreload
# %autoreload 2

# %%
from state_of_the_art.relevance_model.pipeline import Pipeline

pipeline = Pipeline()
model = pipeline.run(epochs=36)
# plot the loss over epochs epochs is the x axis    
pipeline.metrics.plot()
# Out:
# Running with  36  epochs
# 857
# Clasess balance
# score
# 2    481
# 1    178
# 3    141
# 0     55
# 4      2
# Name: count, dtype: int64
# 600 257
# Class distributions over train and test
# Train Labels:  score
# 2    341
# 1    118
# 3    100
# 0     40
# 4      1
# Name: count, dtype: int64
# Test Labels:  score
# 2    140
# 1     60
# 3     41
# 0     15
# 4      1
# Name: count, dtype: int64
# Tracking uri:  file:///Users/jean.machado@getyourguide.com/.tinyws/models/mlruns
# Training mode for  36  epochs
# Epoch 1
# -------------------------------
# loss: 1.633545  [  768/  600]
# /opt/miniconda3/envs/python312/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# loss: 1.328849  [77568/  600]
# loss: 0.731973  [154368/  600]
# loss: 0.621767  [231168/  600]
# ...

# %%
pipeline.metrics.get_dataframe()
# Out:
#     epoch  train_loss  test_loss  train_accuracy  test_accuracy  \
# 0       1    0.994916   1.064853        0.568333       0.544747
# 1       2    0.854306   0.959886        0.655000       0.603113
# 2       3    0.704158   0.857101        0.740000       0.680934
# 3       4    0.561615   0.767500        0.815000       0.719844
# 4       5    0.433200   0.687839        0.868333       0.778210
# 5       6    0.343460   0.627130        0.908333       0.824903
# 6       7    0.263550   0.585731        0.933333       0.836576
# 7       8    0.213652   0.541350        0.940000       0.852140
# 8       9    0.187838   0.573896        0.950000       0.852140
# 9      10    0.168632   0.564645        0.958333       0.867704
# 10     11    0.155677   0.563824        0.956667       0.871595
# 11     12    0.153984   0.610331        0.948333       0.856031
# 12     13    0.134297   0.593207        0.956667       0.871595
# 13     14    0.155829   0.622916        0.953333       0.867704
# ...

# %%
pipeline.save_model(model)
# Out:
# Model saved to  /Users/jean.machado@getyourguide.com/.tinyws/models/model.pth
