# %%
from state_of_the_art.tables.paper_table import PaperTable

df = PaperTable().read(recent_first=True)


df
# Out:
# Events config given:  {'arxiv_papers': {'prevent_duplicates_col': 'abstract_url'}}
#                         abstract_url                 published  \
# 0    http://arxiv.org/abs/2411.01599 2024-11-03 15:07:26+00:00
# 0    http://arxiv.org/abs/2411.01600 2024-11-03 15:10:48+00:00
# 0    http://arxiv.org/abs/2411.01619 2024-11-03 16:13:49+00:00
# 0    http://arxiv.org/abs/2411.01621 2024-11-03 16:18:14+00:00
# 0    http://arxiv.org/abs/2411.01635 2024-11-03 17:18:22+00:00
# ..                               ...                       ...
# 0   https://arxiv.org/abs/cs/0508100 2005-08-23 15:05:12+00:00
# 0   https://arxiv.org/abs/cs/0311004 2003-11-06 07:33:23+00:00
# 0   https://arxiv.org/abs/cs/0202024 2002-02-18 15:23:06+00:00
# 0   https://arxiv.org/abs/cs/0003012 2000-03-06 22:23:00+00:00
# 0   https://arxiv.org/abs/1511.04326 2015-11-12 20:04:31+00:00
#
#                                                 title  \
# 0   Density Functional Theory Study of Surface Sta...
# 0   Graph Fourier Neural ODEs: Bridging Spatial an...
# 0   Phosphorene Junctions as a Platform for Spin-S...
# 0   Can education correct appearance discriminatio...
# 0   Wiedermann-Franz Law and Thermoelectric Inequa...
# ..                                                ...
# 0                  A primer on Answer Set Programming
# 0                         Utility-Probability Duality
# 0                        A note on Darwiche and Pearl
# 0                       Defeasible Reasoning in OSCAR
# 0               ICON Challenge on Algorithm Selection
#
#                                              abstract  \
# 0   CsPbI3 has been recognized as a promising cand...
# 0   Molecular dynamics simulations are crucial for...
# 0   The impact of vacancies on spin-resolved elect...
# 0   This study explores the impact of appearance d...
# 0   We derive a thermoelectric inequality in therm...
# ..                                                ...
# 0   A introduction to the syntax and Semantics of ...
# 0   This paper presents duality between probabilit...
# 0   It is shown that Darwiche and Pearl's postulat...
# 0   This is a system description for the OSCAR def...
# 0   We present the results of the ICON Challenge o...
#
#                 tdw_timestamp                              tdw_uuid  \
# 0  2024-11-05 21:57:40.233601  22a25793-1842-4d2b-9612-146d070b3120
# 0  2024-11-05 21:57:38.883887  411df312-117c-4aee-8112-8a857ad721e1
# 0  2024-11-05 21:57:37.313030  a775ad26-aae9-4d15-a51a-07f95130ccf6
# 0  2024-11-05 21:57:36.373483  ac3f1da5-6bb1-4cff-8657-b8f0ded137d5
# 0  2024-11-05 21:57:35.566607  4214d659-db0b-478a-ae27-aa93925ca597
# ..                        ...                                   ...
# 0  2024-05-24 07:21:40.377510                                  None
# 0  2024-05-24 07:21:40.374869                                  None
# 0  2024-05-24 07:21:40.371498                                  None
# 0  2024-05-24 07:21:40.353565                                  None
# 0  2024-05-24 07:21:40.334866                                  None
#
#                                  pdf_url institution
# 0   https://arxiv.org/pdf/2411.01599.pdf        None
# 0   https://arxiv.org/pdf/2411.01600.pdf        None
# 0   https://arxiv.org/pdf/2411.01619.pdf        None
# 0   https://arxiv.org/pdf/2411.01621.pdf        None
# 0   https://arxiv.org/pdf/2411.01635.pdf        None
# ..                                   ...         ...
# 0                                   None        None
# 0                                   None        None
# 0                                   None        None
# 0                                   None        None
# 0                                   None        None
#
# [49455 rows x 8 columns]

# %%
# filter published only in october 2024
df = df[df['published'].dt.month == 10]

len(df)
# Out:
# 5169
