# %%
from state_of_the_art.read_backlog.read_backlog_table import ReadBacklogTable


#ReadBacklogTable().add_column('time_spend_minutes', 0)

# %%
from state_of_the_art.read_backlog.read_backlog_table import ReadBacklogTable
df = ReadBacklogTable().read()
df
# Out:
# Events config given:  {'arxiv_papers': {'prevent_duplicates_col': 'abstract_url'}}
#                                                  name  \
# 0   Enhancing Poverty Targeting with Spatial Machi...
# 0                            Geo pandas documentation
# 0                        DeepSeek-V3 Technical Report
# 2                                   sota drive folder
# 3                                 sota latest episode
# 4                                         dair papers
# 5   The First Few Tokens Are All You Need: An Effi...
# 6   Counting and Multidiemnsional Poverty Measurement
# 7   Tackling Social Bias against the Poor: A Datas...
# 8                          Calculus by Michael Spivak
# 9                                  Rl implementations
# 10                                     German article
# 0                                               test
#
#                                          resource_url  \
# 0                    https://arxiv.org/pdf/2503.04300
# ...
