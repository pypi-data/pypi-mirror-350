# %% [markdown]
# # Download

# %% [markdown]
# ## Get desired data endpoint

# %% [markdown]
# https://www.eia.gov/opendata/browser/electricity/rto/region-sub-ba-data

# %% [markdown]
# ## Initialize route in Python

# %%
from eia import EIAClient

client = EIAClient() 
route = client.get_data_endpoint('electricity/rto/fuel-type-data')
# Out:
# 2025-05-25 15:12:04,926 - INFO - EIAClient initialized.
# 2025-05-25 15:12:04,926 - INFO - Directly accessing data endpoint metadata for: electricity/rto/fuel-type-data
# 2025-05-25 15:12:04,926 - INFO - Fetching metadata for route: electricity/rto/fuel-type-data

# %% [markdown]
# ## List filtering options
#
# ### Facets: column values

# %%
route.facets
# Out:
# FacetContainer(facets=[respondent, fueltype])

# %%
facet_options = route.facets.respondent.get_values()
facet_options
# Out:
# 2025-05-25 15:12:14,815 - INFO - Fetching facet values for facet 'respondent' in route: electricity/rto/fuel-type-data
# [FacetValue(id='CAL', name='California', description=None),
#  FacetValue(id='MIDA', name='Mid-Atlantic', description=None),
#  FacetValue(id='NY', name='New York', description=None),
#  FacetValue(id='CAR', name='Carolinas', description=None),
#  FacetValue(id='LDWP', name='Los Angeles Department of Water and Power', description=None),
#  FacetValue(id='NYIS', name='New York Independent System Operator', description=None),
#  FacetValue(id='GVL', name='Gainesville Regional Utilities', description=None),
#  FacetValue(id='NWMT', name='NorthWestern Corporation', description=None),
#  FacetValue(id='PSEI', name='Puget Sound Energy, Inc.', description=None),
#  FacetValue(id='TEPC', name='Tucson Electric Power', description=None),
#  FacetValue(id='FMPP', name='Florida Municipal Power Pool', description=None),
#  FacetValue(id='CISO', name='California Independent System Operator', description=None),
#  FacetValue(id='SCEG', name='Dominion Energy South Carolina, Inc.', description=None),
#  FacetValue(id='WAUW', name='Western Area Power Administration - Upper Great Plains West', description=None),
#  FacetValue(id='DUK', name='Duke Energy Carolinas', description=None),
#  FacetValue(id='NEVP', name='Nevada Power Company', description=None),
#  FacetValue(id='SC', name='South Carolina Public Service Authority', description=None),
#  FacetValue(id='GCPD', name='Public Utility District No. 2 of Grant County, Washington', description=None),
#  FacetValue(id='SW', name='Southwest', description=None),
#  FacetValue(id='PNM', name='Public Service Company of New Mexico', description=None),
#  FacetValue(id='JEA', name='JEA', description=None),
#  FacetValue(id='PSCO', name='Public Service Company of Colorado', description=None),
#  FacetValue(id='IID', name='Imperial Irrigation District', description=None),
#  FacetValue(id='PACE', name='PacifiCorp East', description=None),
#  FacetValue(id='TVA', name='Tennessee Valley Authority', description=None),
#  FacetValue(id='CENT', name='Central', description=None),
#  FacetValue(id='US48', name='United States Lower 48', description=None),
#  FacetValue(id='MISO', name='Midcontinent Independent System Operator, Inc.', description=None),
#  FacetValue(id='ERCO', name='Electric Reliability Council of Texas, Inc.', description=None),
#  FacetValue(id='TIDC', name='Turlock Irrigation District', description=None),
#  FacetValue(id='FPL', name='Florida Power & Light Co.', description=None),
#  FacetValue(id='NE', name='New England', description=None),
#  FacetValue(id='BANC', name='Balancing Authority of Northern California', description=None),
#  FacetValue(id='CHPD', name='Public Utility District No. 1 of Chelan County', description=None),
#  FacetValue(id='PJM', name='PJM Interconnection, LLC', description=None),
#  FacetValue(id='PGE', name='Portland General Electric Company', description=None),
#  FacetValue(id='SEC', name='Seminole Electric Cooperative', description=None),
#  FacetValue(id='TEC', name='Tampa Electric Company', description=None),
#  FacetValue(id='TPWR', name='City of Tacoma, Department of Public Utilities, Light Division', description=None),
#  FacetValue(id='WALC', name='Western Area Power Administration - Desert Southwest Region', description=None),
#  FacetValue(id='PACW', name='PacifiCorp West', description=None),
#  FacetValue(id='EPE', name='El Paso Electric Company', description=None),
#  FacetValue(id='YAD', name='Alcoa Power Generating, Inc. - Yadkin Division', description=None),
#  FacetValue(id='HST', name='City of Homestead', description=None),
#  FacetValue(id='DEAA', name='Arlington Valley, LLC', description=None),
#  FacetValue(id='FLA', name='Florida', description=None),
#  FacetValue(id='NW', name='Northwest', description=None),
#  FacetValue(id='MIDW', name='Midwest', description=None),
#  FacetValue(id='SWPP', name='Southwest Power Pool', description=None),
#  FacetValue(id='ISNE', name='ISO New England', description=None),
#  FacetValue(id='WACM', name='Western Area Power Administration - Rocky Mountain Region', description=None),
#  FacetValue(id='CPLE', name='Duke Energy Progress East', description=None),
#  FacetValue(id='FPC', name='Duke Energy Florida, Inc.', description=None),
#  FacetValue(id='AECI', name='Associated Electric Cooperative, Inc.', description=None),
#  FacetValue(id='AVRN', name='Avangrid Renewables, LLC', description=None),
#  FacetValue(id='GRID', name='Gridforce Energy Management, LLC', description=None),
#  FacetValue(id='WWA', name='NaturEner Wind Watch, LLC', description=None),
#  FacetValue(id='SEPA', name='Southeastern Power Administration', description=None),
#  FacetValue(id='TEN', name='Tennessee', description=None),
#  FacetValue(id='TEX', name='Texas', description=None),
#  FacetValue(id='SE', name='Southeast', description=None),
#  FacetValue(id='SCL', name='Seattle City Light', description=None),
#  FacetValue(id='GRIF', name='Griffith Energy, LLC', description=None),
#  FacetValue(id='TAL', name='City of Tallahassee', description=None),
#  FacetValue(id='AEC', name='PowerSouth Energy Cooperative', description=None),
#  FacetValue(id='AVA', name='Avista Corporation', description=None),
#  FacetValue(id='CPLW', name='Duke Energy Progress West', description=None),
#  FacetValue(id='AZPS', name='Arizona Public Service Company', description=None),
#  FacetValue(id='IPCO', name='Idaho Power Company', description=None),
#  FacetValue(id='SPA', name='Southwestern Power Administration', description=None),
#  FacetValue(id='HGMA', name='New Harquahala Generating Company, LLC', description=None),
#  FacetValue(id='EEI', name='Electric Energy, Inc.', description=None),
#  FacetValue(id='GLHB', name='GridLiance', description=None),
#  FacetValue(id='SOCO', name='Southern Company Services, Inc. - Trans', description=None),
#  FacetValue(id='BPAT', name='Bonneville Power Administration', description=None),
#  FacetValue(id='LGEE', name='LG&E and KU Services Company as agent for Louisville Gas and Electric Company and Kentucky Utilities Company', description=None),
#  FacetValue(id='GWA', name='NaturEner Power Watch, LLC', description=None),
#  FacetValue(id='SRP', name='Salt River Project Agricultural Improvement and Power District', description=None),
#  FacetValue(id='DOPD', name='PUD No. 1 of Douglas County', description=None),
#  FacetValue(id='NSB', name='Utilities Commission of New Smyrna Beach', description=None)]

# %% [markdown]
# ### Frequencies: datetime intervals

# %%
route.frequencies
# Out:
# [FrequencyInfo(id='hourly', description='One data point for each hour in UTC time.', query='H', format='YYYY-MM-DD"T"HH24'),
#  FrequencyInfo(id='local-hourly', description='One data point for each hour in local time.', query='LH', format='YYYY-MM-DD"T"HH24TZH')]

# %% [markdown]
# ## Query data

# %%
df_ciso = route.get(
    data_columns=['value'],
    facets={'respondent': 'CISO'},
    frequency='hourly',
    sort=[
        {'column': 'period','direction': 'desc'},
        {'column': 'fueltype', 'direction': 'asc'}
    ]
)

df_ciso
# Out:
# 2025-05-25 15:12:54,002 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 0, Length: All (Pagination)
# 2025-05-25 15:12:54,003 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:12:55,613 - INFO - Received 5000 rows.
# 2025-05-25 15:12:55,614 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 5000, Length: All (Pagination)
# 2025-05-25 15:12:55,614 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:12:57,137 - INFO - Received 5000 rows.
# 2025-05-25 15:12:57,137 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 10000, Length: All (Pagination)
# 2025-05-25 15:12:57,138 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:12:58,750 - INFO - Received 5000 rows.
# 2025-05-25 15:12:58,751 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 15000, Length: All (Pagination)
# 2025-05-25 15:12:58,751 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:00,203 - INFO - Received 5000 rows.
# 2025-05-25 15:13:00,203 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 20000, Length: All (Pagination)
# 2025-05-25 15:13:00,204 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:01,818 - INFO - Received 5000 rows.
# 2025-05-25 15:13:01,818 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 25000, Length: All (Pagination)
# 2025-05-25 15:13:01,818 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:03,482 - INFO - Received 5000 rows.
# 2025-05-25 15:13:03,483 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 30000, Length: All (Pagination)
# 2025-05-25 15:13:03,483 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:05,107 - INFO - Received 5000 rows.
# 2025-05-25 15:13:05,107 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 35000, Length: All (Pagination)
# 2025-05-25 15:13:05,107 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:06,916 - INFO - Received 5000 rows.
# 2025-05-25 15:13:06,916 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 40000, Length: All (Pagination)
# 2025-05-25 15:13:06,917 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:09,643 - INFO - Received 5000 rows.
# 2025-05-25 15:13:09,643 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 45000, Length: All (Pagination)
# 2025-05-25 15:13:09,644 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:12,292 - INFO - Received 5000 rows.
# 2025-05-25 15:13:12,292 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 50000, Length: All (Pagination)
# 2025-05-25 15:13:12,293 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:14,213 - INFO - Received 5000 rows.
# 2025-05-25 15:13:14,214 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 55000, Length: All (Pagination)
# 2025-05-25 15:13:14,214 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:16,283 - INFO - Received 5000 rows.
# 2025-05-25 15:13:16,284 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 60000, Length: All (Pagination)
# 2025-05-25 15:13:16,284 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:18,074 - INFO - Received 5000 rows.
# 2025-05-25 15:13:18,074 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 65000, Length: All (Pagination)
# 2025-05-25 15:13:18,074 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:19,978 - INFO - Received 5000 rows.
# 2025-05-25 15:13:19,979 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 70000, Length: All (Pagination)
# 2025-05-25 15:13:19,979 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:21,912 - INFO - Received 5000 rows.
# 2025-05-25 15:13:21,912 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 75000, Length: All (Pagination)
# 2025-05-25 15:13:21,913 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:23,668 - INFO - Received 5000 rows.
# 2025-05-25 15:13:23,669 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 80000, Length: All (Pagination)
# 2025-05-25 15:13:23,670 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:25,436 - INFO - Received 5000 rows.
# 2025-05-25 15:13:25,437 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 85000, Length: All (Pagination)
# 2025-05-25 15:13:25,437 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:28,254 - INFO - Received 5000 rows.
# 2025-05-25 15:13:28,254 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 90000, Length: All (Pagination)
# 2025-05-25 15:13:28,255 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:29,860 - INFO - Received 5000 rows.
# 2025-05-25 15:13:29,860 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 95000, Length: All (Pagination)
# 2025-05-25 15:13:29,860 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:31,602 - INFO - Received 5000 rows.
# 2025-05-25 15:13:31,603 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 100000, Length: All (Pagination)
# 2025-05-25 15:13:31,603 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:33,511 - INFO - Received 5000 rows.
# 2025-05-25 15:13:33,511 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 105000, Length: All (Pagination)
# 2025-05-25 15:13:33,511 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:35,059 - INFO - Received 5000 rows.
# 2025-05-25 15:13:35,059 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 110000, Length: All (Pagination)
# 2025-05-25 15:13:35,059 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:37,908 - INFO - Received 5000 rows.
# 2025-05-25 15:13:37,909 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 115000, Length: All (Pagination)
# 2025-05-25 15:13:37,909 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:39,502 - INFO - Received 5000 rows.
# 2025-05-25 15:13:39,502 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 120000, Length: All (Pagination)
# 2025-05-25 15:13:39,503 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:41,541 - INFO - Received 5000 rows.
# 2025-05-25 15:13:41,541 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 125000, Length: All (Pagination)
# 2025-05-25 15:13:41,542 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:43,332 - INFO - Received 5000 rows.
# 2025-05-25 15:13:43,332 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 130000, Length: All (Pagination)
# 2025-05-25 15:13:43,333 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:45,242 - INFO - Received 5000 rows.
# 2025-05-25 15:13:45,243 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 135000, Length: All (Pagination)
# 2025-05-25 15:13:45,243 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:46,924 - INFO - Received 5000 rows.
# 2025-05-25 15:13:46,925 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 140000, Length: All (Pagination)
# 2025-05-25 15:13:46,925 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:48,759 - INFO - Received 5000 rows.
# 2025-05-25 15:13:48,759 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 145000, Length: All (Pagination)
# 2025-05-25 15:13:48,760 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:50,409 - INFO - Received 5000 rows.
# 2025-05-25 15:13:50,409 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 150000, Length: All (Pagination)
# 2025-05-25 15:13:50,410 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:52,197 - INFO - Received 5000 rows.
# 2025-05-25 15:13:52,197 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 155000, Length: All (Pagination)
# 2025-05-25 15:13:52,198 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:53,852 - INFO - Received 5000 rows.
# 2025-05-25 15:13:53,852 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 160000, Length: All (Pagination)
# 2025-05-25 15:13:53,853 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:56,012 - INFO - Received 5000 rows.
# 2025-05-25 15:13:56,013 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 165000, Length: All (Pagination)
# 2025-05-25 15:13:56,013 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:58,117 - INFO - Received 5000 rows.
# 2025-05-25 15:13:58,118 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 170000, Length: All (Pagination)
# 2025-05-25 15:13:58,118 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:13:59,892 - INFO - Received 5000 rows.
# 2025-05-25 15:13:59,893 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 175000, Length: All (Pagination)
# 2025-05-25 15:13:59,893 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:01,578 - INFO - Received 5000 rows.
# 2025-05-25 15:14:01,578 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 180000, Length: All (Pagination)
# 2025-05-25 15:14:01,579 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:03,892 - INFO - Received 5000 rows.
# 2025-05-25 15:14:03,892 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 185000, Length: All (Pagination)
# 2025-05-25 15:14:03,892 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:05,742 - INFO - Received 5000 rows.
# 2025-05-25 15:14:05,742 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 190000, Length: All (Pagination)
# 2025-05-25 15:14:05,743 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:07,894 - INFO - Received 5000 rows.
# 2025-05-25 15:14:07,894 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 195000, Length: All (Pagination)
# 2025-05-25 15:14:07,895 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:09,967 - INFO - Received 5000 rows.
# 2025-05-25 15:14:09,967 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 200000, Length: All (Pagination)
# 2025-05-25 15:14:09,967 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:11,941 - INFO - Received 5000 rows.
# 2025-05-25 15:14:11,941 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 205000, Length: All (Pagination)
# 2025-05-25 15:14:11,941 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:14,144 - INFO - Received 5000 rows.
# 2025-05-25 15:14:14,145 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 210000, Length: All (Pagination)
# 2025-05-25 15:14:14,145 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:15,930 - INFO - Received 5000 rows.
# 2025-05-25 15:14:15,930 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 215000, Length: All (Pagination)
# 2025-05-25 15:14:15,930 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:17,835 - INFO - Received 5000 rows.
# 2025-05-25 15:14:17,835 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 220000, Length: All (Pagination)
# 2025-05-25 15:14:17,835 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:19,408 - INFO - Received 5000 rows.
# 2025-05-25 15:14:19,408 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 225000, Length: All (Pagination)
# 2025-05-25 15:14:19,408 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:21,324 - INFO - Received 5000 rows.
# 2025-05-25 15:14:21,325 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 230000, Length: All (Pagination)
# 2025-05-25 15:14:21,325 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:23,526 - INFO - Received 5000 rows.
# 2025-05-25 15:14:23,527 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 235000, Length: All (Pagination)
# 2025-05-25 15:14:23,528 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:25,612 - INFO - Received 5000 rows.
# 2025-05-25 15:14:25,613 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 240000, Length: All (Pagination)
# 2025-05-25 15:14:25,614 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:27,446 - INFO - Received 5000 rows.
# 2025-05-25 15:14:27,446 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 245000, Length: All (Pagination)
# 2025-05-25 15:14:27,446 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:29,163 - INFO - Received 5000 rows.
# 2025-05-25 15:14:29,163 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 250000, Length: All (Pagination)
# 2025-05-25 15:14:29,164 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:31,021 - INFO - Received 5000 rows.
# 2025-05-25 15:14:31,021 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 255000, Length: All (Pagination)
# 2025-05-25 15:14:31,021 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:32,867 - INFO - Received 5000 rows.
# 2025-05-25 15:14:32,867 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 260000, Length: All (Pagination)
# 2025-05-25 15:14:32,868 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:34,662 - INFO - Received 5000 rows.
# 2025-05-25 15:14:34,663 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 265000, Length: All (Pagination)
# 2025-05-25 15:14:34,663 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:36,841 - INFO - Received 5000 rows.
# 2025-05-25 15:14:36,841 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 270000, Length: All (Pagination)
# 2025-05-25 15:14:36,842 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:39,277 - INFO - Received 5000 rows.
# 2025-05-25 15:14:39,277 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 275000, Length: All (Pagination)
# 2025-05-25 15:14:39,278 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:41,174 - INFO - Received 5000 rows.
# 2025-05-25 15:14:41,174 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 280000, Length: All (Pagination)
# 2025-05-25 15:14:41,174 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:43,556 - INFO - Received 5000 rows.
# 2025-05-25 15:14:43,556 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 285000, Length: All (Pagination)
# 2025-05-25 15:14:43,557 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:45,594 - INFO - Received 5000 rows.
# 2025-05-25 15:14:45,594 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 290000, Length: All (Pagination)
# 2025-05-25 15:14:45,595 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:47,468 - INFO - Received 5000 rows.
# 2025-05-25 15:14:47,468 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 295000, Length: All (Pagination)
# 2025-05-25 15:14:47,468 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:49,298 - INFO - Received 5000 rows.
# 2025-05-25 15:14:49,298 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 300000, Length: All (Pagination)
# 2025-05-25 15:14:49,299 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:51,152 - INFO - Received 5000 rows.
# 2025-05-25 15:14:51,153 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 305000, Length: All (Pagination)
# 2025-05-25 15:14:51,153 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:53,151 - INFO - Received 5000 rows.
# 2025-05-25 15:14:53,152 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 310000, Length: All (Pagination)
# 2025-05-25 15:14:53,152 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:55,178 - INFO - Received 5000 rows.
# 2025-05-25 15:14:55,178 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 315000, Length: All (Pagination)
# 2025-05-25 15:14:55,179 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:57,353 - INFO - Received 5000 rows.
# 2025-05-25 15:14:57,353 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 320000, Length: All (Pagination)
# 2025-05-25 15:14:57,354 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:14:59,020 - INFO - Received 5000 rows.
# 2025-05-25 15:14:59,021 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 325000, Length: All (Pagination)
# 2025-05-25 15:14:59,021 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:01,376 - INFO - Received 5000 rows.
# 2025-05-25 15:15:01,376 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 330000, Length: All (Pagination)
# 2025-05-25 15:15:01,376 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:03,924 - INFO - Received 5000 rows.
# 2025-05-25 15:15:03,924 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 335000, Length: All (Pagination)
# 2025-05-25 15:15:03,925 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:06,261 - INFO - Received 5000 rows.
# 2025-05-25 15:15:06,261 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 340000, Length: All (Pagination)
# 2025-05-25 15:15:06,261 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:08,647 - INFO - Received 5000 rows.
# 2025-05-25 15:15:08,647 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 345000, Length: All (Pagination)
# 2025-05-25 15:15:08,647 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:10,767 - INFO - Received 5000 rows.
# 2025-05-25 15:15:10,768 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 350000, Length: All (Pagination)
# 2025-05-25 15:15:10,768 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:13,089 - INFO - Received 5000 rows.
# 2025-05-25 15:15:13,089 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 355000, Length: All (Pagination)
# 2025-05-25 15:15:13,090 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:15,478 - INFO - Received 5000 rows.
# 2025-05-25 15:15:15,479 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 360000, Length: All (Pagination)
# 2025-05-25 15:15:15,479 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:19,779 - INFO - Received 5000 rows.
# 2025-05-25 15:15:19,779 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 365000, Length: All (Pagination)
# 2025-05-25 15:15:19,779 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:23,460 - INFO - Received 5000 rows.
# 2025-05-25 15:15:23,461 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 370000, Length: All (Pagination)
# 2025-05-25 15:15:23,461 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:27,970 - INFO - Received 5000 rows.
# 2025-05-25 15:15:27,970 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 375000, Length: All (Pagination)
# 2025-05-25 15:15:27,971 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:30,838 - INFO - Received 5000 rows.
# 2025-05-25 15:15:30,839 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 380000, Length: All (Pagination)
# 2025-05-25 15:15:30,840 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:34,835 - INFO - Received 5000 rows.
# 2025-05-25 15:15:34,836 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 385000, Length: All (Pagination)
# 2025-05-25 15:15:34,836 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:38,027 - INFO - Received 5000 rows.
# 2025-05-25 15:15:38,028 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 390000, Length: All (Pagination)
# 2025-05-25 15:15:38,028 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:42,309 - INFO - Received 5000 rows.
# 2025-05-25 15:15:42,312 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 395000, Length: All (Pagination)
# 2025-05-25 15:15:42,312 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:47,115 - INFO - Received 5000 rows.
# 2025-05-25 15:15:47,116 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 400000, Length: All (Pagination)
# 2025-05-25 15:15:47,116 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:51,983 - INFO - Received 5000 rows.
# 2025-05-25 15:15:51,984 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 405000, Length: All (Pagination)
# 2025-05-25 15:15:51,984 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:15:56,863 - INFO - Received 5000 rows.
# 2025-05-25 15:15:56,863 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 410000, Length: All (Pagination)
# 2025-05-25 15:15:56,864 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:16:00,439 - INFO - Received 5000 rows.
# 2025-05-25 15:16:00,440 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 415000, Length: All (Pagination)
# 2025-05-25 15:16:00,440 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:16:04,330 - INFO - Received 5000 rows.
# 2025-05-25 15:16:04,331 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 420000, Length: All (Pagination)
# 2025-05-25 15:16:04,331 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:16:07,733 - INFO - Received 5000 rows.
# 2025-05-25 15:16:07,733 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 425000, Length: All (Pagination)
# 2025-05-25 15:16:07,733 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:16:10,978 - INFO - Received 5000 rows.
# 2025-05-25 15:16:10,979 - INFO - Fetching data for route: electricity/rto/fuel-type-data - Offset: 430000, Length: All (Pagination)
# 2025-05-25 15:16:10,979 - INFO - Fetching data for route: electricity/rto/fuel-type-data/data
# 2025-05-25 15:16:14,667 - INFO - Received 2510 rows.
# 2025-05-25 15:16:14,667 - INFO - Received less than page limit, assuming end of data.
# 2025-05-25 15:16:14,977 - INFO - Automatically converted 'period' column to datetime with UTC.
# 2025-05-25 15:16:15,085 - INFO - Automatically converted 'value' column to numeric.
#                           period respondent  \
# 0      2025-05-25 03:00:00+00:00       CISO
# 1      2025-05-25 03:00:00+00:00       CISO
# ...                          ...        ...
# 432508 2019-01-01 00:00:00+00:00       CISO
# 432509 2019-01-01 00:00:00+00:00       CISO
#
#                                respondent-name fueltype    type-name   value  \
# 0       California Independent System Operator      COL         Coal     0.0
# 1       California Independent System Operator       NG  Natural Gas  3489.0
# ...                                        ...      ...          ...     ...
# 432508  California Independent System Operator      WAT        Hydro  2403.0
# 432509  California Independent System Operator      WND         Wind  2497.0
#
#           value-units
# 0       megawatthours
# 1       megawatthours
# ...               ...
# 432508  megawatthours
# 432509  megawatthours
#
# [432510 rows x 7 columns]

# %% [markdown]
# ## Export data

# %%
df_ciso.to_csv('../../../data/fuel-type-data_ciso.csv', index=False)
